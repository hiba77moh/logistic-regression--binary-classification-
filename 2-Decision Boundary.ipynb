# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import plot_data, sigmoid, draw_vthresh
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## Dataset
# - `X` has 6 training examples, each with two features
# - `y` is either `0` or `1`

# %%
X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1]).reshape(-1,1)

# %% [markdown]
# fig,ax = plt.subplots(1,1,figsize=(4,4))
# plot_data(X_train, y_train, ax)
#
# ax.axis([0, 4, 0, 3.5])
# ax.set_ylabel('$x_1$', fontsize=12)
# ax.set_xlabel('$x_0$', fontsize=12)
# plt.show()

# %% [markdown]
# ## plot data

# %%
fig,ax = plt.subplots(1,1,figsize=(4,4))
plot_data(X, y, ax)

ax.axis([0, 4, 0, 3.5])
ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Logistic regression model
#
#
# a logistic regression model on this data has the form    :  $f(x) = g(w_0x_0+w_1x_1 + b)$
#
#   where $g(z) = \frac{1}{1+e^{-z}}$, which is the sigmoid function
#
#
# * Let's say that after trained the model we got the parameters as $b = -3, w_0 = 1, w_1 = 1$. That is,
#
#     $f(x) = g(x_0+x_1-3)$

# %% [markdown]
# * Remember : For a logistic regression model, $z = \mathbf{w} \cdot \mathbf{x} + b$. Therefore,
#
#   if $\mathbf{w} \cdot \mathbf{x} + b >= 0$, the model predicts $y=1$
#
#   if $\mathbf{w} \cdot \mathbf{x} + b < 0$, the model predicts $y=0$

# %% [markdown]
# ### Plotting decision boundary
#
# so this model predicts $y=1$ if
#
#  $-3 + x_0+x_1 >= 0$
#
#   $x_0+x_1 > 3$
#
# Let's see what this looks like graphically.

# %%
# Choose values between 0 and 6
x0 = np.arange(0,6)

x1 = 3 - x0
fig,ax = plt.subplots(1,1,figsize=(5,4))
# Plot the decision boundary
ax.plot(x0,x1, c="b")
ax.axis([0, 4, 0, 3.5])

# Fill the region below the line
ax.fill_between(x0,x1, alpha=0.2)

# Plot the original data
plot_data(X,y,ax)
ax.set_ylabel(r'$x_1$')
ax.set_xlabel(r'$x_0$')
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# * Any point in the shaded region (under the line) is classified as $y=0$.  Any point on or above the line is classified as $y=1$. This line is known as the "decision boundary".
